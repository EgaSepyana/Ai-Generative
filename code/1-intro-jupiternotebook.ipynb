# %% [markdown]
# ## Jupyter Shortcut
#
# Shift + enter : new code cell below curent cell
# Ctrl +  enter : execute cell
# A : new code cell above selected cell
# B : new code cell before selected cell
# DD : Delete cell
# C : copy selected cell
# V : paste selected cell
# Alt + enter : run cell and insert below

# %%
x = [1,2,3,4,5]
x

# %%
x.append(6)
x
