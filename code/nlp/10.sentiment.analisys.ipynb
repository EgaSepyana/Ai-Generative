# %%
from textblob import TextBlob

# %%
sentence_1 = "i had a great time at the movie it was really funny"
sentence_2 = "i had a great time at the movie but the parking was terrible"
sentence_3 = "i had a great time at the movie but the parking wasn't great"
sentence_4 = "i went to see a movie"

# %%
sentence_1
# Out:
# 'i had a great time at the movie it was really funny'

# %%
senttiment_score_1 = TextBlob(sentence_1)
print(sentence_1)
senttiment_score_1.sentiment.polarity
# Out:
# i had a great time at the movie it was really funny
# 0.525

# %%
senttiment_score_2 = TextBlob(sentence_2)
print(sentence_2)
senttiment_score_2.sentiment.polarity
# Out:
# i had a great time at the movie but the parking was terrible
# -0.09999999999999998

# %%
senttiment_score_3 = TextBlob(sentence_3)
print(sentence_3)
senttiment_score_3.sentiment.polarity
# Out:
# i had a great time at the movie but the parking wasn't great
# 0.8

# %%
senttiment_score_4 = TextBlob(sentence_4)
print(sentence_4)
senttiment_score_4.sentiment.polarity
# Out:
# i went to see a movie
# 0.0

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader_sentiment = SentimentIntensityAnalyzer()

# %%
print(sentence_1)
vader_sentiment.polarity_scores(sentence_1)
# Out:
# i had a great time at the movie it was really funny
# {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.807}

# %%
print(sentence_2)
vader_sentiment.polarity_scores(sentence_2)
# Out:
# i had a great time at the movie but the parking was terrible
# {'neg': 0.234, 'neu': 0.621, 'pos': 0.144, 'compound': -0.3818}

# %%
print(sentence_3)
vader_sentiment.polarity_scores(sentence_3)
# Out:
# i had a great time at the movie but the parking wasn't great
# {'neg': 0.247, 'neu': 0.611, 'pos': 0.142, 'compound': -0.4387}

# %%
print(sentence_4)
vader_sentiment.polarity_scores(sentence_4)
# Out:
# i went to see a movie
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
import transformers
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1793, in _LazyModule._get_module(self, module_name)
#    1792 try:
# -> 1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/pipelines/__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/image_processing_utils.py:21
#      20 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 21 from .image_transforms import center_crop, normalize, rescale
#      22 from .image_utils import ChannelDimension
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/image_utils.py:59
#      58 if is_torchvision_available():
# ---> 59     from torchvision.transforms import InterpolationMode
#      61     pil_torch_interpolation_mapping = {
#      62         PILImageResampling.NEAREST: InterpolationMode.NEAREST,
#      63         PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      67         PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      68     }
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/torchvision/__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/torchvision/_meta_registrations.py:26
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/torchvision/_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 2
#       1 import transformers
# ----> 2 from transformers import pipeline
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1781, in _LazyModule.__getattr__(self, name)
#    1779     value = Placeholder
#    1780 elif name in self._class_to_module.keys():
# -> 1781     module = self._get_module(self._class_to_module[name])
#    1782     value = getattr(module, name)
#    1783 elif name in self._modules:
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1795, in _LazyModule._get_module(self, module_name)
#    1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
# -> 1795     raise RuntimeError(
#    1796         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1797         f" traceback):\n{e}"
#    1798     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1793, in _LazyModule._get_module(self, module_name)
#    1792 try:
# -> 1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/pipelines/__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/image_processing_utils.py:21
#      20 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 21 from .image_transforms import center_crop, normalize, rescale
#      22 from .image_utils import ChannelDimension
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/image_utils.py:59
#      58 if is_torchvision_available():
# ---> 59     from torchvision.transforms import InterpolationMode
#      61     pil_torch_interpolation_mapping = {
#      62         PILImageResampling.NEAREST: InterpolationMode.NEAREST,
#      63         PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      67         PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      68     }
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/torchvision/__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/torchvision/_meta_registrations.py:26
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/torchvision/_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Use a pipeline as a high-level helper
# ----> 2 from transformers import pipeline
#       4 pipe = pipeline("text-classification", model="finiteautomata/bertweet-base-sentiment-analysis")
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1781, in _LazyModule.__getattr__(self, name)
#    1779     value = Placeholder
#    1780 elif name in self._class_to_module.keys():
# -> 1781     module = self._get_module(self._class_to_module[name])
#    1782     value = getattr(module, name)
#    1783 elif name in self._modules:
#
# File ~/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1795, in _LazyModule._get_module(self, module_name)
#    1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
# -> 1795     raise RuntimeError(
#    1796         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1797         f" traceback):\n{e}"
#    1798     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
