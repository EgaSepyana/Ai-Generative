# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 5.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: numpy>=1.23 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from matplotlib) (2.2.2)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 3.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 KB 7.6 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 4.4 MB/s eta 0:00:0000:0100:01
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 3.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.5 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.8 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 KB 4.0 MB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.22.4
#   Downloading numpy-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 KB 4.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.2 pandas-2.2.3 pytz-2025.1 tzdata-2025.1

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
tokens =  ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
tokens
# Out:
# ['the',
#  'rise',
#  'of',
#  'artificial',
#  'intelligence',
#  'has',
#  'led',
#  'to',
#  'significant',
#  'advancements',
#  'in',
#  'natural',
#  'language',
#  'processing',
#  'computer',
#  'vision',
#  'and',
#  'other',
#  'fields',
#  'machine',
#  'learning',
#  'algorithms',
#  'are',
#  'becoming',
#  'more',
#  'sophisticated',
#  'enabling',
#  'computers',
#  'to',
#  'perform',
#  'complex',
#  'tasks',
#  'that',
#  'were',
#  'once',
#  'thought',
#  'to',
#  'be',
#  'the',
#  'exclusive',
#  'domain',
#  'of',
#  'humans',
#  'with',
#  'the',
#  'advent',
#  'of',
#  'deep',
#  'learning',
#  'neural',
#  'networks',
#  'have',
#  'become',
#  'even',
#  'more',
#  'powerful',
#  'capable',
#  'of',
#  'processing',
#  'vast',
#  'amounts',
#  'of',
#  'data',
#  'and',
#  'learning',
#  'from',
#  'it',
#  'in',
#  'ways',
#  'that',
#  'were',
#  'not',
#  'possible',
#  'before',
#  'as',
#  'a',
#  'result',
#  'ai',
#  'is',
#  'increasingly',
#  'being',
#  'used',
#  'in',
#  'a',
#  'wide',
#  'range',
#  'of',
#  'industries',
#  'from',
#  'healthcare',
#  'to',
#  'finance',
#  'to',
#  'transportation',
#  'and',
#  'its',
#  'impact',
#  'is',
#  'only',
#  'set',
#  'to',
#  'grow',
#  'in',
#  'the',
#  'years',
#  'to',
#  'come']

# %%
unigrams = (pd.Series(nltk.ngrams(tokens , 1))).value_counts()
unigrams[:10]
# Out:
# (to,)            7
# (of,)            6
# (the,)           4
# (in,)            4
# (and,)           3
# (learning,)      3
# (processing,)    2
# (from,)          2
# (is,)            2
# (a,)             2
# Name: count, dtype: int64

# %%
unigrams[:10].sort_values().plot.barh(color="lightsalmon" , width=.9 , figsize=(14 , 8))
plt.title("10 Most requently Occuring Unigrams")
# Out:
# Text(0.5, 1.0, '10 Most requently Occuring Unigrams')

# %%
bigrams = (pd.Series(nltk.ngrams(tokens , 2))).value_counts()
bigrams[:10]
# Out:
# (that, were)                   2
# (rise, of)                     1
# (of, artificial)               1
# (artificial, intelligence)     1
# (intelligence, has)            1
# (has, led)                     1
# (led, to)                      1
# (to, significant)              1
# (the, rise)                    1
# (significant, advancements)    1
# Name: count, dtype: int64

# %%
trigrams = (pd.Series(nltk.ngrams(tokens , 3))).value_counts()
trigrams[:10]
# Out:
# (the, rise, of)                    1
# (rise, of, artificial)             1
# (of, artificial, intelligence)     1
# (artificial, intelligence, has)    1
# (intelligence, has, led)           1
# (has, led, to)                     1
# (led, to, significant)             1
# (to, significant, advancements)    1
# (significant, advancements, in)    1
# (advancements, in, natural)        1
# Name: count, dtype: int64
