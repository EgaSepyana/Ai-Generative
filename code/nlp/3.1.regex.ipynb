# %%
import re

# %%
my_folder = "C:\desktop\notes"
my_folder
# Out:
# 'C:\\desktop\notes'

# %%
result_seach = re.search("pattern" , r'string to contain the pattern')

# %%
print(result_seach)
# Out:
# <re.Match object; span=(22, 29), match='pattern'>

# %%
result_seach_2 = re.search("pattern" , r"the pharse to find isn't in this string")
print(result_seach_2)
# Out:
# None

# %%
string = r"sara was able to help me find the items I needed quickly"

# %%
new_string = re.sub("sara" , "sarah" , string)
print(new_string)
# Out:
# sarah was able to help me find the items I needed quickly

# %%
costumers_reviewers = ['sam was a great help to me in the store', 
 'the cashier was very rude to me, I think her name was eleanor', 
 'amazing work from sadeen!', 
 'sarah was able to help me find the items i needed quickly', 
 'lucy is such a great addition to the team', 
 'great service from sara she found me what i wanted']

# %%
sarahs_reviews = []

# %%
pattern_to_search = r"sarah?"

# %%
for string in costumers_reviewers:
    if (re.search(pattern_to_search , string)):
        sarahs_reviews.append(string)

# %%
sarahs_reviews
# Out:
# ['sarah was able to help me find the items i needed quickly',
#  'great service from sara she found me what i wanted']

# %%
a_reviews = []
pattern_to_find = r"^a"

for string in costumers_reviewers:
    if (re.search(pattern_to_find, string)):
        a_reviews.append(string)

# %%
a_reviews
# Out:
# ['amazing work from sadeen!']

# %%
y_reviews = []
pattern_to_find = r"y$"

for string in costumers_reviewers:
    if (re.search(pattern_to_find, string)):
        y_reviews.append(string)

# %%
y_reviews
# Out:
# ['sarah was able to help me find the items i needed quickly']
