# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: click in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: tqdm in /home/ega/Documents/Reaserch/Ai-Generative/venv/lib/python3.10/site-packages (from nltk) (4.67.1)

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/ega/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
en_stopwords = stopwords.words("english")
en_stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
sentence = "it was too far to go to the shop and he did not want her to walk"

# %%
sentence
# Out:
# 'it was too far to go to the shop and he did not want her to walk'

# %%
sentance_no_stopwords = " ".join([word for word in sentence.split() if word not in en_stopwords])

# %%
sentance_no_stopwords
# Out:
# 'far go shop want walk'

# %%
en_stopwords.remove("did")
en_stopwords.remove("not")
en_stopwords.append("go")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 en_stopwords.remove("did")
#       2 en_stopwords.remove("not")
#       3 en_stopwords.append("go")
#
# ValueError: list.remove(x): x not in list

# %%
"did" in en_stopwords
# Out:
# False

# %%
sentance_no_stopwords_custom = " ".join([word for word in sentence.split() if word not in en_stopwords])

# %%
sentance_no_stopwords_custom
# Out:
# 'far shop did not want walk'
